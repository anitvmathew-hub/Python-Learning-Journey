# %% [markdown]
# # Python Assignment 1: Data Structures - Strings & Tuples

# %% [markdown]
# ## Strings (Concatenation, Slicing and Other methods) :

# %% [markdown]
# ### 1. String Concatenation:

# %%
#string 1
string1 = "Hello "

#string 2
name = input("Enter your Name: ")
string2= string1 + name
print(string2)

# string 3
string3 = ", welcome to Python programming"

# concatenate the existing string with string3
output_string =  string2 + string3

# display the output string
print(output_string)
# Out:
# Enter your Name:  Anit
# Hello Anit
# Hello Anit, welcome to Python programming.

# %% [markdown]
# ### 2. String Slicing and Indexing:

# %%
text = "Hello Anit, welcome to Python programming"

#a. Print the first character of the string.
print(text[0])

#b. Print the last character of the string. 
print(text[-1])'

#c. Print the first 5 characters of the string.
print(text[:5])

#d. Print the last 11 characters of the string. 
print(text[-11:])

#e. Print the string in reverse. 
print(text[::-1])

#f. Use slicing and print the word “Python” from the existing string.
print(text[23:29])
# Out:
# H
# g
# Hello
# programming
# gnimmargorp nohtyP ot emoclew ,tinA olleH
# Python

# %% [markdown]
# ### 3. String Methods:

# %%
#Write a Python program that takes a string,strM = “Python beginner tutorial” and perform the following tasks:

strM = "Python beginner tutorial"    


#a. Convert the sentence to uppercase. 
print(strM.upper())
   
#b. Convert the sentence to lowercase.
print(strM.lower())    

#c. Use Capitalize and return the sentence to the original input form. 
print(strM.capitalize())   

#d. Count the total number of occurrences of character t in the string.
count=strM.count('t')
print("Total number of occurances of character t in the string=",count)

#e. Replace all occurrences of “Python” with “Machine Learning” in the input string strM = “Python beginner tutorial”
print(strM.replace("Python","Machine Learning"))
# Out:
# PYTHON BEGINNER TUTORIAL
# python beginner tutorial
# Python beginner tutorial
# Total number of occurances of character t in the string= 3
# Machine Learning beginner tutorial

# %% [markdown]
# ### Tuples (Creation, Modification and Access) :

# %%
#Create 1st tuple with values -> (10, 20, 30), 2nd tuple with values -> (40, 50, 60):

t1=(10,20,30)
t2=(40,50,60)

#a. Concatenate the two tuples and store it in “t_combine”
t_combine= t1 + t2
print(t_combine)

#b. Repeat the elements of “t_combine” 3 times
print(t_combine*3)

#c. Access the 3rd element from “t_combine”
print(t_combine[2])
      
#d. Access the first three elements from “t_combine”
print(t_combine[0:3])

#e. Access the last three elements from “t_combine”
print(t_combine[-3:])
# Out:
# (10, 20, 30, 40, 50, 60)
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# 30
# (10, 20, 30)
# (40, 50, 60)
