# %% [markdown]
# # Python Assignment 3: While Loop, For loop and Function

# %% [markdown]
# ## While loop & Control Statements :
# #### (else, break, continue, pass)

# %% [markdown]
# ###                                               Number Guessing Game

# %% [markdown]
# #### Problem Statement:
# ##### Create a Python program that implements a simple number guessing game using a while loop. The program should make use of control statements such as else, break, and continue.

# %%
import random
# Generate random number between 1 and 10
secret_number = random.randint(1, 10)
attempts = 3
while attempts > 0:
    guess = int(input("Guess the number (between 1 and 10): "))

    if guess < 1 or guess > 10:
        print("Your guess is out of valid range. Please guess a number between 1 and 10.")
        continue

    attempts -= 1

    if guess == secret_number:
        print("Congratulations! You guessed the correct number.")
        break
    elif guess > secret_number:
        print("Try again ! Your guess is greater than the secret number.")
    else: 
        print("Try again ! Your guess is lower than the secret number. ")
else:
    print("Better luck next time!")
# Out:
# Guess the number (between 1 and 10):  8
# Try again ! Your guess is lower than the secret number.
# Guess the number (between 1 and 10):  9
# Congratulations! You guessed the correct number.

# %% [markdown]
# ## For Loop:

# %% [markdown]
# ### Multiplication Table Generator

# %% [markdown]
# #### Problem Statement:
# ##### Create a Python program that generates and prints a multiplication table (from 1 to 10) for a given number using a for loop and the range function.

# %%
number = int(input("Enter the number for which you want the multiplication table: "))

for i in range(1, 11):
    print(f"{number} x {i} = {number * i}")
# Out:
# Enter the number for which you want the multiplication table:  5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# ## Function:

# %% [markdown]
# ### BMI Calculator

# %% [markdown]
# ##### Problem Statement: Create a Python program that calculates the Body Mass Index (BMI).
# ##### Hint: BMI = weight (kg) / [height (m)]²

# %%
def calculate_bmi(weight, height):
    return  weight / (height ** 2)

w = float(input("Enter your weight in kg: "))
h = float(input("Enter your height in meters: "))

BMI = calculate_bmi(w, h)
rounded_BMI=round(BMI,4)
print(f"Your BMI is {rounded_BMI}")
# Out:
# Enter your weight in kg:  65
# Enter your height in meters:  158
# Your BMI is 0.0026
